# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Volumes/Extreme SSD/Python_Projects/NIAA Project/data/data_in_one_row_without_spouses.csv')

# %%
df.head()
# Out:
#                             nama orang   geb/overl.   organ.  \
# 0              Aa, zr. W. van der (N)   1908-1942/5      GZB
# 1  Aalbers, dr. Joh. Godefr., arts (N)    1910-1992      NZG
# 2              Aalders, zr. Jacoba (N)    1910-1999       SZ
# 3                    Abeel, David (VS)    1804-1846    ABCFM
# 4          Abkoude, ds. F.N.M. van (N)    1895-1988  mandiri
#
#               werkgebied en -soort  werkperiode  \
# 0  Rantepao (Sulsel), verpleegster    1932-1933
# 1                             Deli    1937-1946
# 2  Bojonegoro, verpleegster in Zzh  1939-1942/6
# 3            Batavia, bij Medhurst         1831
# 4     pred. gem. Temanggung, MJava    1925-1942
#
#                                       bijzonderheden  Unnamed: 6 Unnamed: 7  \
# 0  ~ 1933 F.R.O. Steller, contr. BB, z.v. hp E.T....         NaN        NaN
# 1                        1942-45 Japanse internering         NaN        NaN
# ...

# %%
# Create a new dataframe with the first two columns and the last column
df1 = df.iloc[:, [0, 1, -1]]

# %%
# Write to csv
df1.to_csv('/Volumes/Extreme SSD/Python_Projects/NIAA Project/FINAL_PARSED_DATA/bio_data.csv', index=False)
