# %%
import pandas as pd
import numpy as np

# %%
bio = pd.read_csv('/Volumes/Extreme SSD/Python_Projects/NIAA Project/FINAL/bio_data_with_origin_dates.csv')

# %%
bio.head()
# Out:
#                         nama orang   geb/overl.  id  actual id  Unnamed: 4  \
# 0               Aa, zr. W. van der  1908-1942/5   0        NaN         NaN
# 1  Aalbers, dr. Joh. Godefr., arts    1910-1992   1        NaN         NaN
# 2              Aalders, zr. Jacoba    1910-1999   2        NaN         NaN
# 3                     Abeel, David    1804-1846   3        NaN         NaN
# 4          Abkoude, ds. F.N.M. van    1895-1988   4        NaN         NaN
#
#                      origin birthYear deathYear
# 0               Netherlands      1908    1942/5
# 1               Netherlands      1910      1992
# 2               Netherlands      1910      1999
# 3  United States of America      1804      1846
# 4               Netherlands      1895      1988

# %%
bio = bio.drop(columns=['actual id', 'Unnamed: 4'])

# %%
bio.head()
# Out:
#                         nama orang   geb/overl.  id                    origin  \
# 0               Aa, zr. W. van der  1908-1942/5   0               Netherlands
# 1  Aalbers, dr. Joh. Godefr., arts    1910-1992   1               Netherlands
# 2              Aalders, zr. Jacoba    1910-1999   2               Netherlands
# 3                     Abeel, David    1804-1846   3  United States of America
# 4          Abkoude, ds. F.N.M. van    1895-1988   4               Netherlands
#
#   birthYear deathYear
# 0      1908    1942/5
# 1      1910      1992
# 2      1910      1999
# 3      1804      1846
# 4      1895      1988

# %%
bio.to_csv('/Volumes/Extreme SSD/Python_Projects/NIAA Project/FINAL/bio_FINAL.csv', index=False)
