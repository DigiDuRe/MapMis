# %% [markdown]
# This notebook contains additional dataparsing steps that are taken after all the processing done by glp500 and JJ.
#
# As input we use the excl sheets:
# - bio_FINAL Julia working on sex.xlsx
# - events_FINAL curated by Julia.xlsx
# - locations(KEY) curated Julia.xlsx
# - spouses_FINAL curated by Julia.xlsx

# %%
import pandas as pd
import re
from datetime import datetime

# %%
bio = pd.read_excel('./input_data/bio_FINAL Julia working on sex.xlsx')
events = pd.read_excel('./input_data/events_FINAL curated by Julia.xlsx')
locations = pd.read_excel('./input_data/locations(KEY) curated Julia.xlsx')
spouses = pd.read_excel('./input_data/spouses_FINAL curated by Julia.xlsx')

# %%
# Panda settings for showing data (this is foremost done to more easily explore the data while processing it)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# In the bio table we are going to drop the origin column, since there are multiple errors in the translation (e.g. Austr. should be Australia and not Austria). Next we isolate the infomation about places (which are in Column Unnamed:6 ) and which are in between () e.g. (N) and (VS) and translate these into a new column with location (country) of birth.

# %%
bio = bio.drop('origin', axis=1)

# %%
bio['oorsprong'] = bio['Unnamed: 6'].str.extract(r'\((.*?)\)')

# %% [markdown]
# Next, we want to replace the names of the country with a location file generated by JJ. We load the column as df after which we create a join between the two.

# %%
locations.head()
# Out:
#          abr          location
# 0       (VS)  Verenigde Staten
# 1        (N)         Nederland
# 2   (Zwits.)       Zwitserland
# 3  (Rusland)           Rusland
# 4    (China)             China

# %%
locations['abr'] = locations['abr'].str.replace(r'[()]', '', regex=True)

# %%
bio_location = pd.merge(bio, locations, left_on='oorsprong', right_on='abr', how='left')

# %% [markdown]
# Now we drop the two columns which are not needed anymore.

# %%
bio_location = bio_location.drop('oorsprong', axis=1)
bio_location = bio_location.drop('abr', axis=1)

# %% [markdown]
# For the sake of cleaning the data we convert the id to integer.

# %%
bio_location['id'] = bio_location['id'].astype('Int64')

# %%
bio_location.head()
# Out:
#                         nama orang   geb/overl.  id birthYear deathYear  \
# 0               Aa, zr. W. van der  1908-1942/5   0      1908    1942/5
# 1  Aalbers, dr. Joh. Godefr., arts    1910-1992   1      1910      1992
# 2              Aalders, zr. Jacoba    1910-1999   2      1910      1999
# 3                     Abeel, David    1804-1846   3      1804      1846
# 4          Abkoude, ds. F.N.M. van    1895-1988   4      1895      1988
#
#                             Unnamed: 6 Sex           location
# 0              Aa, zr. W. van der (N)     V         Nederland
# 1  Aalbers, dr. Joh. Godefr., arts (N)  NaN         Nederland
# 2              Aalders, zr. Jacoba (N)    V         Nederland
# 3                    Abeel, David (VS)    M  Verenigde Staten
# 4          Abkoude, ds. F.N.M. van (N)    M         Nederland

# %% [markdown]
# Now we extract the title from the column "nama orang" these are.

# %%
bio_location['titel'] = bio_location['nama orang'].str.extract(r'(dr\.|jhr\.|ds\.)', flags=re.IGNORECASE, expand=False)

# %% [markdown]
# Now remove the titles from the name.

# %%
bio_location['titel'] = bio_location['nama orang'].str.extract(
    r'(dr\.|jhr\.|ds\.|drs.|jkvr.)', 
    flags=re.IGNORECASE, 
    expand=False
)

# %%
bio_location['nama orang'] = bio_location['nama orang'].str.replace(
    r'(dr\.|jhr\.|ds\.|drs.|jkvr.)\s*', 
    '', 
    flags=re.IGNORECASE, 
    regex=True
)

# %% [markdown]
# People have their profession ("beroep" in Dutch) in their name field. We extract this and parse it to a new field "beroep", since in some case people have multiple "beroepen" we add them into one column seperated by a ,

# %%
# Define the pattern of different professions (beroepen)
beroep_pattern = r'(zr\.|zr|arts|zdl\.|zendeling|evangel.|ond\.|zwm\.|zdl|diakones|diacones|theoloog)'

# Find the matches
bio_location['beroep(en)'] = bio_location['nama orang'].str.findall(beroep_pattern, flags=re.IGNORECASE)

# Join matches with commas (if any)
bio_location['beroep(en)'] = bio_location['beroep(en)'].apply(lambda x: ', '.join(x) if x else None)

# %% [markdown]
# Now we delete the professions from "nama orang"

# %%
bio_location['nama orang'] = bio_location['nama orang'].str.replace(
    r'(zr\.|zr|arts|zdl\.|verpl|zendeling|evangel.|ond\.|zwm\.|zwm|zdl|diakones|diacones|theoloog)\.?\s*',
    '',
    flags=re.IGNORECASE,
    regex=True
)

bio_location.head()
# Out:
#                 nama orang   geb/overl.  id birthYear deathYear  \
# 0           Aa, W. van der  1908-1942/5   0      1908    1942/5
# 1  Aalbers, Joh. Godefr.,     1910-1992   1      1910      1992
# 2          Aalders, Jacoba    1910-1999   2      1910      1999
# 3             Abeel, David    1804-1846   3      1804      1846
# 4      Abkoude, F.N.M. van    1895-1988   4      1895      1988
#
#                             Unnamed: 6 Sex           location titel beroep(en)
# 0              Aa, zr. W. van der (N)     V         Nederland   NaN        zr.
# 1  Aalbers, dr. Joh. Godefr., arts (N)  NaN         Nederland   dr.       arts
# 2              Aalders, zr. Jacoba (N)    V         Nederland   NaN        zr.
# 3                    Abeel, David (VS)    M  Verenigde Staten   NaN       None
# 4          Abkoude, ds. F.N.M. van (N)    M         Nederland   ds.       None

# %%
bio_location.rename(columns={
    'birthYear': 'geboortejaar',
    'deathYear': 'sterfjaar',
    'Sex ': 'geslacht',
    'location' : 'oorsprong',
    'Unnamed: 6' : "original_input"     
}, inplace=True)

# %%
bio_location['titulatuur_geslacht'] = bio_location['nama orang'].str.extract(r'(mw\.| mw| ms.| ms)', flags=re.IGNORECASE, expand=False)

# %%
bio_location['nama orang'] = bio_location['nama orang'].str.replace(
    r'(mw\.|mw| ms.| ms)\.?\s*',
    '',
    flags=re.IGNORECASE,
    regex=True
)

# %%
bio_location.head(10)
# Out:
#                                      nama orang   geb/overl.  id geboortejaar  \
# 0                                Aa, W. van der  1908-1942/5   0         1908
# 1                       Aalbers, Joh. Godefr.,     1910-1992   1         1910
# 2                               Aalders, Jacoba    1910-1999   2         1910
# 3                                  Abeel, David    1804-1846   3         1804
# 4                           Abkoude, F.N.M. van    1895-1988   4         1895
# 5                           Ackermann, Gustav,     1876-1955   5         1876
# 6  Adriaanse, A.J., zie Gemerts-Adriaanse, A.J.          NaN   6          NaN
# 7                                 Adriaanse, L.    1856-1947   7         1856
# 8                             Adriani, Nicolaus    1865-1926   8         1865
# 9                             Aebersold, W.E.,     1903-1996   9         1903
#
#   sterfjaar                                original_input geslacht  \
# 0    1942/5                       Aa, zr. W. van der (N)         V
# 1      1992           Aalbers, dr. Joh. Godefr., arts (N)      NaN
# 2      1999                       Aalders, zr. Jacoba (N)        V
# 3      1846                             Abeel, David (VS)        M
# 4      1988                   Abkoude, ds. F.N.M. van (N)        M
# 5      1955                   Ackermann, Gustav, zdl. (D)        M
# 6       NaN  Adriaanse, A.J., zie Gemerts-Adriaanse, A.J.      NaN
# 7      1947                         Adriaanse, ds. L. (N)      NaN
# 8      1926                     Adriani, dr. Nicolaus (N)        M
# 9      1996                 Aebersold, W.E., zdl (Zwits.)      NaN
#
#           oorsprong titel beroep(en) titulatuur_geslacht
# 0         Nederland   NaN        zr.                 NaN
# 1         Nederland   dr.       arts                 NaN
# 2         Nederland   NaN        zr.                 NaN
# 3  Verenigde Staten   NaN       None                 NaN
# 4         Nederland   ds.       None                 NaN
# 5         Duitsland   NaN       zdl.                 NaN
# 6               NaN   NaN       None                 NaN
# 7         Nederland   ds.       None                 NaN
# 8         Nederland   dr.       None                 NaN
# 9       Zwitserland   NaN        zdl                 NaN

# %%
bio_location['achternaam'] = bio_location['nama orang'].str.extract(r'^([^,]+)')

# %%
bio_location['verwijzing'] = bio_location['nama orang'].str.extract(r'(zie\s+.*)', flags=re.IGNORECASE)
bio_location['nama orang'] = bio_location['nama orang'].str.replace(r'\s*zie\s+.*', '', flags=re.IGNORECASE, regex=True)

# %%
bio_location.head(25)
# Out:
#                     nama orang   geb/overl.  id geboortejaar sterfjaar  \
# 0               Aa, W. van der  1908-1942/5   0         1908    1942/5
# 1      Aalbers, Joh. Godefr.,     1910-1992   1         1910      1992
# 2              Aalders, Jacoba    1910-1999   2         1910      1999
# 3                 Abeel, David    1804-1846   3         1804      1846
# 4          Abkoude, F.N.M. van    1895-1988   4         1895      1988
# 5          Ackermann, Gustav,     1876-1955   5         1876      1955
# 6             Adriaanse, A.J.,          NaN   6          NaN       NaN
# 7                Adriaanse, L.    1856-1947   7         1856      1947
# 8            Adriani, Nicolaus    1865-1926   8         1865      1926
# 9            Aebersold, W.E.,     1903-1996   9         1903      1996
# 10               Agter, H.J.,     1892-1957  10         1892      1957
# 11             Akersloot, J.,   1790/1-1830  11       1790/1      1830
# 12    Akerson, Rev. Leroy Lind    1892-1921  12         1892      1921
# 13      Akkeren, Philippus v,     1910-1993  13         1910      1993
# 14                Albers, C.,     1837-1920  14         1837      1920
# 15         Albrecht, Magdalene    1895-1968  15         1895      1968
# 16     Alewijn, Anton Godfried    1877-1954  16         1877      1954
# 17                  Alfs, Anna    1877-1967  17         1877      1967
# 18              Alkema, B.M.,     1868-1942  18         1868      1942
# 19        Alkema, Menno Theod.    1894-1963  19         1894      1963
# 20           Allaart Bernard,     1908-1999  20         1908      1999
# 21  Allaart, Dirk J. Bergardus    1898-1945  21         1898      1945
# 22      Allstrom, Rev. Eric W.          NaN  22          NaN       NaN
# 23            Alm, Rev. Ragnar   1900-1964+  23         1900     1964+
# 24            Alphen, J.J. van       1848/9  24       1848/9       NaN
#
#                                   original_input geslacht         oorsprong  \
# 0                        Aa, zr. W. van der (N)         V         Nederland
# 1            Aalbers, dr. Joh. Godefr., arts (N)      NaN         Nederland
# 2                        Aalders, zr. Jacoba (N)        V         Nederland
# 3                              Abeel, David (VS)        M  Verenigde Staten
# 4                    Abkoude, ds. F.N.M. van (N)        M         Nederland
# 5                    Ackermann, Gustav, zdl. (D)        M         Duitsland
# 6   Adriaanse, A.J., zie Gemerts-Adriaanse, A.J.      NaN               NaN
# 7                          Adriaanse, ds. L. (N)      NaN         Nederland
# 8                      Adriani, dr. Nicolaus (N)        M         Nederland
# 9                  Aebersold, W.E., zdl (Zwits.)      NaN       Zwitserland
# 10                          Agter, H.J., zdl (N)      NaN         Nederland
# 11                       Akersloot, J., zdl. (N)      NaN         Nederland
# 12                 Akerson, Rev. Leroy Lind (VS)        M  Verenigde Staten
# 13             Akkeren, dr. Philippus v, zdl (N)      NaN         Nederland
# 14                           Albers, C., zdl (N)      NaN         Nederland
# 15                   Albrecht, zr. Magdalene (D)        V         Duitsland
# 16              Alewijn, jhr. Anton Godfried (N)        M         Nederland
# 17                                Alfs, Anna (D)        V         Duitsland
# 18                         Alkema, B.M., zdl (N)      NaN         Nederland
# 19                      Alkema, Menno Theod. (N)        M         Nederland
# 20                     Allaart Bernard, arts (N)      NaN         Nederland
# 21            Allaart, ds. Dirk J. Bergardus (N)      NaN         Nederland
# 22                   Allstrom, Rev. Eric W. (VS)      NaN  Verenigde Staten
# 23                     Alm, Rev. Ragnar (Skand.)      NaN       Scandinavië
# 24                              Alphen, J.J. van      NaN               NaN
#
#    titel beroep(en) titulatuur_geslacht       achternaam  \
# 0    NaN        zr.                 NaN               Aa
# 1    dr.       arts                 NaN          Aalbers
# 2    NaN        zr.                 NaN          Aalders
# 3    NaN       None                 NaN            Abeel
# 4    ds.       None                 NaN          Abkoude
# 5    NaN       zdl.                 NaN        Ackermann
# 6    NaN       None                 NaN        Adriaanse
# 7    ds.       None                 NaN        Adriaanse
# 8    dr.       None                 NaN          Adriani
# 9    NaN        zdl                 NaN        Aebersold
# 10   NaN        zdl                 NaN            Agter
# 11   NaN       zdl.                 NaN        Akersloot
# 12   NaN       None                 NaN          Akerson
# 13   dr.        zdl                 NaN          Akkeren
# 14   NaN        zdl                 NaN           Albers
# 15   NaN        zr.                 NaN         Albrecht
# 16  jhr.       None                 NaN          Alewijn
# 17   NaN       None                 NaN             Alfs
# 18   NaN        zdl                 NaN           Alkema
# 19   NaN       None                 NaN           Alkema
# 20   NaN       arts                 NaN  Allaart Bernard
# 21   ds.       None                 NaN          Allaart
# 22   NaN       None                 NaN         Allstrom
# 23   NaN       None                 NaN              Alm
# 24   NaN       None                 NaN           Alphen
#
#                      verwijzing
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6   zie Gemerts-Adriaanse, A.J.
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
# 13                          NaN
# 14                          NaN
# 15                          NaN
# 16                          NaN
# 17                          NaN
# 18                          NaN
# 19                          NaN
# 20                          NaN
# 21                          NaN
# 22                          NaN
# 23                          NaN
# 24                          NaN

# %%
bio_location['infix'] = bio_location['nama orang'].str.extract(
    r'(van der|van de|van den|van|de)', 
    flags=re.IGNORECASE, 
    expand=False
)

bio_location['nama orang'] = bio_location['nama orang'].str.replace(
    r'\b(van der|van de|van den|van|de)\b\s*',
    '',
    flags=re.IGNORECASE,
    regex=True
)

# %%
bio_location['voornamen of voorletters'] = bio_location['nama orang'].str.extract(r',\s*(.*)')

# %%
bio_location['voornamen of voorletters'] = bio_location['voornamen of voorletters'].str.replace(',', '', regex=False)

# %%
bio_location.head(50)
# Out:
#                             nama orang   geb/overl.  id geboortejaar  \
# 0                              Aa, W.   1908-1942/5   0         1908
# 1              Aalbers, Joh. Godefr.,     1910-1992   1         1910
# 2                      Aalders, Jacoba    1910-1999   2         1910
# 3                         Abeel, David    1804-1846   3         1804
# 4                     Abkoude, F.N.M.     1895-1988   4         1895
# 5                  Ackermann, Gustav,     1876-1955   5         1876
# 6                     Adriaanse, A.J.,          NaN   6          NaN
# 7                        Adriaanse, L.    1856-1947   7         1856
# 8                    Adriani, Nicolaus    1865-1926   8         1865
# 9                    Aebersold, W.E.,     1903-1996   9         1903
# 10                       Agter, H.J.,     1892-1957  10         1892
# 11                     Akersloot, J.,   1790/1-1830  11       1790/1
# 12            Akerson, Rev. Leroy Lind    1892-1921  12         1892
# 13              Akkeren, Philippus v,     1910-1993  13         1910
# 14                        Albers, C.,     1837-1920  14         1837
# 15                 Albrecht, Magdalene    1895-1968  15         1895
# 16             Alewijn, Anton Godfried    1877-1954  16         1877
# 17                          Alfs, Anna    1877-1967  17         1877
# 18                      Alkema, B.M.,     1868-1942  18         1868
# 19                Alkema, Menno Theod.    1894-1963  19         1894
# 20                   Allaart Bernard,     1908-1999  20         1908
# 21          Allaart, Dirk J. Bergardus    1898-1945  21         1898
# 22              Allstrom, Rev. Eric W.          NaN  22          NaN
# 23                    Alm, Rev. Ragnar   1900-1964+  23         1900
# 24                       Alphen, J.J.        1848/9  24       1848/9
# 25                Alphen, Pauline El.     1885-1945  25         1885
# 26                   Alt, Gustav Adolf    1856-1921  26         1856
# 27                  Alt, Marg. Adriana    1883-1962  27         1883
# 28                      Ameler, August    1877-1940  28         1877
# 29                   Amstutz, Daniel,     1906-1991  29         1906
# 30            Andel, Corn. Cath. Herm.    1913-1997  30         1913
# 31                        Andel, H.A.     1875-1945  31         1875
# 32                      Anders, Emilie    1868-1922  32         1868
# 33                    Anderson, E.G.O.          NaN  33          NaN
# 34                     Anken, Roelfke     1906-2001  34         1906
# 35                     Anskohl, Martin    1883-1945  35         1883
# 36                   Antheunisse, A.,     1896-1990  36         1896
# 37          Archer, Rev. Raymond LeRoy    1887-1970  37         1887
# 38               Arff-Schumacher, Elli    1865-1914  38         1865
# 39  Arkel, G. , later G. Kiewiet-Arkel    1903-1984  39         1903
# 40                     Arms, William,     1802-1889  41         1802
# 41                        Arps, B.J.,     1898-1962  42         1898
# 42                           As, A. ,     1886-1920  43         1886
# 43                   Asselt, Gerrit ,     1832-1910  44         1832
# 44                  Augusteijn, Jolina    1905-2000  45         1905
# 45                         Baan, Maria    1896-1994  46         1896
# 46                       Baan, M.J.G.,          NaN  47          NaN
# 47                Baarbé, Cornelia, ,     1894-1981  48         1894
# 48                    Baarbé, Hendrika        1896-  49         1896
# 49                     Baarda, M.J. ,     1854-1940  50         1854
#
#    sterfjaar                                              original_input  \
# 0     1942/5                                     Aa, zr. W. van der (N)
# 1       1992                         Aalbers, dr. Joh. Godefr., arts (N)
# 2       1999                                     Aalders, zr. Jacoba (N)
# 3       1846                                           Abeel, David (VS)
# 4       1988                                 Abkoude, ds. F.N.M. van (N)
# 5       1955                                 Ackermann, Gustav, zdl. (D)
# 6        NaN                Adriaanse, A.J., zie Gemerts-Adriaanse, A.J.
# 7       1947                                       Adriaanse, ds. L. (N)
# 8       1926                                   Adriani, dr. Nicolaus (N)
# 9       1996                               Aebersold, W.E., zdl (Zwits.)
# 10      1957                                        Agter, H.J., zdl (N)
# 11      1830                                     Akersloot, J., zdl. (N)
# 12      1921                               Akerson, Rev. Leroy Lind (VS)
# 13      1993                           Akkeren, dr. Philippus v, zdl (N)
# 14      1920                                         Albers, C., zdl (N)
# 15      1968                                 Albrecht, zr. Magdalene (D)
# 16      1954                            Alewijn, jhr. Anton Godfried (N)
# 17      1967                                              Alfs, Anna (D)
# 18      1942                                       Alkema, B.M., zdl (N)
# 19      1963                                    Alkema, Menno Theod. (N)
# 20      1999                                   Allaart Bernard, arts (N)
# 21      1945                          Allaart, ds. Dirk J. Bergardus (N)
# 22       NaN                                 Allstrom, Rev. Eric W. (VS)
# 23     1964+                                   Alm, Rev. Ragnar (Skand.)
# 24       NaN                                            Alphen, J.J. van
# 25      1945                                 Alphen, Pauline El. van (N)
# 26      1921                                       Alt, Gustav Adolf (D)
# 27      1962                                      Alt, Marg. Adriana (N)
# 28      1940                                          Ameler, August (D)
# 29      1991                              Amstutz, Daniel, zdl. (Zwits.)
# 30      1997                            Andel, zr. Corn. Cath. Herm. (N)
# 31      1945                                     Andel, dr. H.A. van (N)
# 32      1922                                          Anders, Emilie (D)
# 33       NaN                                       Anderson, E.G.O. (GB)
# 34      2001                                  Anken, zr. Roelfke van (N)
# 35      1945                                         Anskohl, Martin (D)
# 36      1990                                   Antheunisse, A., ond. (N)
# 37      1970                             Archer, Rev. Raymond LeRoy (VS)
# 38      1914                                   Arff-Schumacher, Elli (D)
# 39      1984  Arkel, zr. G. van, diakones (N) later G. Kiewiet-van Arkel
# 40      1889                                     Arms, William, zdl (VS)
# 41      1962                                         Arps, B.J., zdl (N)
# 42      1920                                         As, A. van, zdl (N)
# 43      1910                                 Asselt, Gerrit van, zdl (N)
# 44      2000                                  Augusteijn, zr. Jolina (N)
# 45      1994                                         Baan, zr. Maria (N)
# 46       NaN                               Baan, M.J.G., zie Voorst-Baan
# 47      1981                        Baarbé, Cornelia, ond., evangel. (N)
# 48       NaN                                    Baarbé, zr. Hendrika (N)
# 49      1940                                   Baarda, M.J. van, zdl (N)
#
#    geslacht         oorsprong titel      beroep(en) titulatuur_geslacht  \
# 0         V         Nederland   NaN             zr.                 NaN
# 1       NaN         Nederland   dr.            arts                 NaN
# 2         V         Nederland   NaN             zr.                 NaN
# 3         M  Verenigde Staten   NaN            None                 NaN
# 4         M         Nederland   ds.            None                 NaN
# 5         M         Duitsland   NaN            zdl.                 NaN
# 6       NaN               NaN   NaN            None                 NaN
# 7       NaN         Nederland   ds.            None                 NaN
# 8         M         Nederland   dr.            None                 NaN
# 9       NaN       Zwitserland   NaN             zdl                 NaN
# 10      NaN         Nederland   NaN             zdl                 NaN
# 11      NaN         Nederland   NaN            zdl.                 NaN
# 12        M  Verenigde Staten   NaN            None                 NaN
# 13      NaN         Nederland   dr.             zdl                 NaN
# 14      NaN         Nederland   NaN             zdl                 NaN
# 15        V         Duitsland   NaN             zr.                 NaN
# 16        M         Nederland  jhr.            None                 NaN
# 17        V         Duitsland   NaN            None                 NaN
# 18      NaN         Nederland   NaN             zdl                 NaN
# 19        M         Nederland   NaN            None                 NaN
# 20      NaN         Nederland   NaN            arts                 NaN
# 21      NaN         Nederland   ds.            None                 NaN
# 22      NaN  Verenigde Staten   NaN            None                 NaN
# 23      NaN       Scandinavië   NaN            None                 NaN
# 24      NaN               NaN   NaN            None                 NaN
# 25        V         Nederland   NaN            None                 NaN
# 26        M         Duitsland   NaN            None                 NaN
# 27        V         Nederland   NaN            None                 NaN
# 28        M         Duitsland   NaN            None                 NaN
# 29        M       Zwitserland   NaN            zdl.                 NaN
# 30        V         Nederland   NaN             zr.                 NaN
# 31      NaN         Nederland   dr.            None                 NaN
# 32        V         Duitsland   NaN            None                 NaN
# 33      NaN   Groot-Brittanië   NaN            None                 NaN
# 34        V         Nederland   NaN             zr.                 NaN
# 35      NaN         Duitsland   NaN            None                 NaN
# 36        M         Nederland   NaN            ond.                 NaN
# 37        M  Verenigde Staten   NaN            None                 NaN
# 38        V         Duitsland   NaN            None                 NaN
# 39        V         Nederland   NaN   zr., diakones                 NaN
# 40        M  Verenigde Staten   NaN             zdl                 NaN
# 41      NaN         Nederland   NaN             zdl                 NaN
# 42      NaN         Nederland   NaN             zdl                 NaN
# 43      NaN         Nederland   NaN             zdl                 NaN
# 44        V         Nederland   NaN             zr.                 NaN
# 45        V         Nederland   NaN             zr.                 NaN
# 46      NaN               NaN   NaN            None                 NaN
# 47        V         Nederland   NaN  ond., evangel.                 NaN
# 48        V         Nederland   NaN             zr.                 NaN
# 49      NaN         Nederland   NaN             zdl                 NaN
#
#          achternaam                   verwijzing    infix  \
# 0                Aa                          NaN  van der
# 1           Aalbers                          NaN       de
# 2           Aalders                          NaN       de
# 3             Abeel                          NaN      NaN
# 4           Abkoude                          NaN       de
# 5         Ackermann                          NaN      NaN
# 6         Adriaanse  zie Gemerts-Adriaanse, A.J.      NaN
# 7         Adriaanse                          NaN      NaN
# 8           Adriani                          NaN      NaN
# 9         Aebersold                          NaN      NaN
# 10            Agter                          NaN      NaN
# 11        Akersloot                          NaN      NaN
# 12          Akerson                          NaN      NaN
# 13          Akkeren                          NaN      NaN
# 14           Albers                          NaN      NaN
# 15         Albrecht                          NaN      NaN
# 16          Alewijn                          NaN      NaN
# 17             Alfs                          NaN      NaN
# 18           Alkema                          NaN      NaN
# 19           Alkema                          NaN      NaN
# 20  Allaart Bernard                          NaN      NaN
# 21          Allaart                          NaN      NaN
# 22         Allstrom                          NaN      NaN
# 23              Alm                          NaN      NaN
# 24           Alphen                          NaN      van
# 25           Alphen                          NaN      van
# 26              Alt                          NaN      NaN
# 27              Alt                          NaN      NaN
# 28           Ameler                          NaN      NaN
# 29          Amstutz                          NaN      NaN
# 30            Andel                          NaN       de
# 31            Andel                          NaN       de
# 32           Anders                          NaN       de
# 33         Anderson                          NaN       de
# 34            Anken                          NaN      van
# 35          Anskohl                          NaN      NaN
# 36      Antheunisse                          NaN      NaN
# 37           Archer                          NaN      NaN
# 38  Arff-Schumacher                          NaN      NaN
# 39            Arkel                          NaN      van
# 40             Arms                          NaN      NaN
# 41             Arps                          NaN      NaN
# 42               As                          NaN      van
# 43           Asselt                          NaN      van
# 44       Augusteijn                          NaN      NaN
# 45             Baan                          NaN      NaN
# 46             Baan              zie Voorst-Baan      NaN
# 47           Baarbé                          NaN      NaN
# 48           Baarbé                          NaN      NaN
# 49           Baarda                          NaN      van
#
#       voornamen of voorletters
# 0                          W.
# 1                Joh. Godefr.
# 2                       Jacoba
# 3                        David
# 4                      F.N.M.
# 5                      Gustav
# 6                         A.J.
# 7                           L.
# 8                     Nicolaus
# 9                        W.E.
# 10                       H.J.
# 11                         J.
# 12             Rev. Leroy Lind
# 13                Philippus v
# 14                         C.
# 15                   Magdalene
# 16              Anton Godfried
# 17                        Anna
# 18                       B.M.
# 19                Menno Theod.
# 20
# 21           Dirk J. Bergardus
# 22                Rev. Eric W.
# 23                 Rev. Ragnar
# 24                       J.J.
# 25                Pauline El.
# 26                Gustav Adolf
# 27               Marg. Adriana
# 28                      August
# 29                     Daniel
# 30           Corn. Cath. Herm.
# 31                       H.A.
# 32                      Emilie
# 33                      E.G.O.
# 34                    Roelfke
# 35                      Martin
# 36                         A.
# 37          Rev. Raymond LeRoy
# 38                        Elli
# 39  G.  later G. Kiewiet-Arkel
# 40                    William
# 41                       B.J.
# 42                        A.
# 43                    Gerrit
# 44                      Jolina
# 45                       Maria
# 46                      M.J.G.
# 47                  Cornelia
# 48                    Hendrika
# 49                      M.J.

# %%
# Extract the first 4-digit number from 'geboortejaar'
bio_location['geboortejaar_int'] = bio_location['geboortejaar'].astype(str).str.extract(r'(\d{4})')

# Convert to integer (optional, depending on if you want NaN or errors on failure)
bio_location['geboortejaar_int'] = bio_location['geboortejaar_int'].astype(float).astype('Int64')

# %%
# Extract the first 4-digit number from 'sterfjaar'
bio_location['sterfjaar_int'] = bio_location['sterfjaar'].astype(str).str.extract(r'(\d{4})')

# Convert to integer
bio_location['sterfjaar_int'] = bio_location['sterfjaar_int'].astype(float).astype('Int64')

# %%
bio_location['bron'] = None
bio_location['wildcard'] = None
bio_location['opmerkingen_wildcard'] = None
bio_location['verwzijzing_id'] = None

# %%
bio_location.columns.tolist()
# Out:
# ['nama orang',
#  'geb/overl.',
#  'id',
#  'geboortejaar',
#  'sterfjaar',
#  'original_input',
#  'geslacht',
#  'oorsprong',
#  'titel',
#  'beroep(en)',
#  'titulatuur_geslacht',
#  'achternaam',
#  'verwijzing',
#  'infix',
#  'voornamen of voorletters',
#  'geboortejaar_int',
#  'sterfjaar_int',
#  'bron',
#  'wildcard',
#  'opmerkingen_wildcard',
#  'verwzijzing_id']

# %%
# change the order of the columns and drop "nama orang"

bio_location = bio_location[[
    'id', 
    'original_input', 
    'titel',
    'achternaam',
    'infix',
    'voornamen of voorletters',
    'beroep(en)',
    'titulatuur_geslacht',
    'geslacht',
    'oorsprong',
    'verwijzing',
    'verwzijzing_id',
    'geb/overl.',
    'geboortejaar',
    'geboortejaar_int',
    'sterfjaar',
    'sterfjaar_int',
    'bron',
    'wildcard',
    'opmerkingen_wildcard'
]]

# %%
date_str = datetime.today().strftime('%m_%d_%Y')
filename = f'bio_{date_str}.xlsx'

# %%
bio_location.to_excel(filename, index=False)
